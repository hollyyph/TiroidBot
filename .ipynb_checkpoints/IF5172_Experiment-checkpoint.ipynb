# %% [markdown]
# # Questions Classifier
#
# Kelompok B - IF5172 Datawarehouse & Data Mining
# - Anindya Prameswari			13518034
# - William Fu 				13518055
# - Hollyana Puteri Haryono		18218013
# - Adriel Gustino P. Situmorang		18218047
# - Arief Purnama Muharram		23521013

# %%
# !pip install --upgrade nltk
# !pip install gensim==3.6.0
# !pip install xgboost
# Out:
# Requirement already satisfied: nltk in c:\users\temp\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: tqdm in c:\users\temp\anaconda3\lib\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: joblib in c:\users\temp\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\temp\anaconda3\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: click in c:\users\temp\anaconda3\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: colorama in c:\users\temp\anaconda3\lib\site-packages (from click->nltk) (0.4.4)
# Requirement already satisfied: gensim==3.6.0 in c:\users\temp\anaconda3\lib\site-packages (3.6.0)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\temp\anaconda3\lib\site-packages (from gensim==3.6.0) (1.22.1)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\temp\anaconda3\lib\site-packages (from gensim==3.6.0) (1.8.0)
# Requirement already satisfied: six>=1.5.0 in c:\users\temp\anaconda3\lib\site-packages (from gensim==3.6.0) (1.16.0)
# Requirement already satisfied: smart-open>=1.2.1 in c:\users\temp\anaconda3\lib\site-packages (from gensim==3.6.0) (5.2.1)
# Requirement already satisfied: xgboost in c:\users\temp\anaconda3\lib\site-packages (1.6.0)
# Requirement already satisfied: scipy in c:\users\temp\anaconda3\lib\site-packages (from xgboost) (1.8.0)
# Requirement already satisfied: numpy in c:\users\temp\anaconda3\lib\site-packages (from xgboost) (1.22.1)

# %%
# import necessary package
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import warnings
warnings.filterwarnings("ignore")
import pickle

from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\TEMP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\TEMP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    label                                           question
# 0    500          Bagaimana cara mengobati penyakit Graves?
# 1    500                    Apa obat untuk penyakit Graves?
# 2    500  Obat apa yang dapat menyembuhkan penyakit Graves?
# 3    300                Apa gejala terkena penyakit Graves?
# 4    300     Bagaimana tanda-tanda terkena penyakit Graves?

# %%
# Summary
df['label'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Preprocessing

# %%
# read the dictionary of slang-formal words
df_formal_words = pd.read_csv('colloquial-indonesian-lexicon.csv')
slangs_words = df_formal_words[['slang','formal']]

# %%
df['question_clean'] = df['question'].apply(lambda x: re.sub("'", '', x.lower()))

# %%
# DATA CLEANING
# Tokenize
df['question_clean'] = df['question_clean'].apply(nltk.word_tokenize)
print('Tokenization complete.')

df[['question_clean']].head()
# Out:
# Tokenization complete.
#                                       question_clean
# 0  [bagaimana, cara, mengobati, penyakit, graves, ?]
# 1            [apa, obat, untuk, penyakit, graves, ?]
# 2  [obat, apa, yang, dapat, menyembuhkan, penyaki...
# 3        [apa, gejala, terkena, penyakit, graves, ?]
# 4  [bagaimana, tanda-tanda, terkena, penyakit, gr...

# %%
# Remove stop words
stop_words=set(nltk.corpus.stopwords.words("indonesian"))
df['question_clean'] = df['question_clean'].apply(lambda x: [item for item in x if item not in stop_words])
print('Stop words removed.')

df[['question_clean']].head()
# Out:
# Stop words removed.
#                                 question_clean
# 0             [mengobati, penyakit, graves, ?]
# 1                  [obat, penyakit, graves, ?]
# 2    [obat, menyembuhkan, penyakit, graves, ?]
# 3       [gejala, terkena, penyakit, graves, ?]
# 4  [tanda-tanda, terkena, penyakit, graves, ?]

# %%
# Remove numbers, punctuation and special characters (only keep words)
regex = '[a-z]+'
df['question_clean'] = df['question_clean'].apply(lambda x: [item for item in x if re.match(regex, item)])
print('Numbers, punctuation and special characters removed.')

df[['question_clean']].head()
# Out:
# Numbers, punctuation and special characters removed.
#                              question_clean
# 0             [mengobati, penyakit, graves]
# 1                  [obat, penyakit, graves]
# 2    [obat, menyembuhkan, penyakit, graves]
# 3       [gejala, terkena, penyakit, graves]
# 4  [tanda-tanda, terkena, penyakit, graves]

# %%
df.head()
# Out:
#    label                                           question  \
# 0      5         Bagaimana cara mengobati penyakit Grave's?
# 1      5                   Apa obat untuk penyakit Grave's?
# 2      5  Obat apa yang dapat menyembuhkan penyakit Grav...
# 3      3               Apa gejala terkena penyakit Grave's?
# 4      3    Bagaimana tanda-tanda terkena penyakit Grave's?
#
#                              question_clean
# 0             [mengobati, penyakit, graves]
# 1                  [obat, penyakit, graves]
# 2    [obat, menyembuhkan, penyakit, graves]
# 3       [gejala, terkena, penyakit, graves]
# 4  [tanda-tanda, terkena, penyakit, graves]

# %%
# def preprocess(message):
#   # Process message as follows:
#   # 1. Remove on alphabetical symbols
#   # 2. Case folding: turn all patterns
#   # 3. Converts question to array of words
#   replace_graves = re.sub("'", '', message)
#   letters_only = re.sub('[^a-zA-Z]', ' ', replace_graves)
#   lower_case = letters_only.lower()
#   words = np.array(lower_case.split(), dtype='object')
#   formals = np.array([], dtype=object)  
#   for word in words:
#     df_tmp = slangs_words[slangs_words['slang'] == word].reset_index() 
    
#     # Remove any informal lingo if exists
#     if df_tmp.shape[0] != 0:
#       formal = df_tmp['formal'][0]
#       formals = np.append(formals, formal)
#     else:
#       formals = np.append(formals, word)
    
#     # Remove any Indonesian stopwords
#     words_stopped = np.array([w for w in formals if w not in stopwords.words("indonesian")], dtype=object)

#   # return the preprocessed chat
#   return " ".join(words_stopped)

# %%
df_prep = df.copy()
df_prep = df_prep.drop(columns=['question'])
df_prep.head()
# Out:
#    label                            question_clean
# 0      5             [mengobati, penyakit, graves]
# 1      5                  [obat, penyakit, graves]
# 2      5    [obat, menyembuhkan, penyakit, graves]
# 3      3       [gejala, terkena, penyakit, graves]
# 4      3  [tanda-tanda, terkena, penyakit, graves]

# %% [markdown]
# ### Train/Test Split

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

df_attr = np.array(df_prep['question_clean'])
df_label = np.array(df_prep['label'])

preprocess_train, preprocess_test, y_train, y_test = train_test_split(
    df_attr, df_label, test_size=0.3,
    random_state=42, stratify=df_label
)

print(f"Train dataset: {preprocess_train.shape}")
print(f"Test dataset: {preprocess_test.shape}")
# Out:
# Train dataset: (280,)
# Test dataset: (120,)

# %% [markdown]
# ### Modelling

# %% [markdown]
# #### Word2vec Vectorizer

# %%
# # Classification using word2vec vectorizer

# from gensim.models import Word2Vec
# from sklearn.pipeline import Pipeline
# from sklearn.svm import SVC
# from sklearn.naive_bayes import GaussianNB
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.neural_network import MLPClassifier
# from sklearn.ensemble import GradientBoostingClassifier
# from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# import xgboost as xgb

# vec_model = Word2Vec(df_prep['question_clean'])
# w2v = dict(zip(vec_model.wv.index_to_key, vec_model.wv.syn0))

# class Vectorizer(object):
    
#     def __init__(self, vec):
#         self.vec = vec
#         self.dim = len(vec.values())

#     def fit(self, X, y):
#         return self

#     def transform(self, X):
#         return np.array([np.mean([self.vec[w] for w in words if w in self.vec] or [np.zeros(self.dim)], axis=0) for words in X])

# class Classifier(object):
    
#     def __init__(self, model, param):
#         self.model = model
#         self.param = param
#         self.gs = GridSearchCV(self.model, self.param, cv=5, error_score=0, refit=True)        

#     def fit(self, X, y):        
#         return self.gs.fit(X, y)

#     def predict(self, X):
#         return self.gs.predict(X)

# clf_models = {
#     'Naive Bayes': GaussianNB(),
#     'Decision Tree': DecisionTreeClassifier(),  
#     'Perceptron': MLPClassifier(),
#     'Gradient Boosting': GradientBoostingClassifier(),
#     'XGBoost': xgb.XGBClassifier()
# }

# clf_params = {
#     'Naive Bayes': { },
#     'Decision Tree': { 'min_samples_split': [2, 5] }, 
#     'Perceptron': { 'activation': ['tanh', 'relu'] },
#     'Gradient Boosting': { 'learning_rate': [0.05, 0.1], 'min_samples_split': [2, 5] },
#     'XGBoost': { "max_depth": [3, 4, 5], "learning_rate": [0.1, 0.01, 0.05], "gamma": [0, 0.25, 1], "reg_lambda": [0, 1] }
# }

# X_train, X_test, y_train, y_test = train_test_split(df_prep['question_clean'], df_prep['label'], test_size=0.2, random_state=42)

# for key in clf_models.keys():
    
#     clf = Pipeline([('Word2Vec vectorizer', Vectorizer(w2v)), ('Classifier', Classifier(clf_models[key], clf_params[key]))])
    
#     clf.fit(X_train, y_train)
#     y_pred = clf.predict(X_test)
    
#     print(key, ':')
#     print("Accuracy: %1.3f \tPrecision: %1.3f \tRecall: %1.3f \t\tF1: %1.3f\n" % (accuracy_score(y_test, y_pred), precision_score(y_test, y_pred, average='macro'), recall_score(y_test, y_pred, average='macro'), f1_score(y_test, y_pred, average='macro')))

# %% [markdown]
# ### TFIDF Vectorizer
# Dalam eksperimen ini, dimanfaatkan vectorizer TFIDF untuk mentransformasi teks menjadi vector. Vectorizer ini memiliki tambahan komponen TFIDF di atas CountVectorizer. Adapun metrik pengukuran yang dimanfaatkan dalam vectorizer ini adalah sebagai berikut.
#
# TF(t,d) + IDF(t)
#
# Keterangan:
# - *TF(t,d)*: Term Frequency, banyaknya kemunculan term t dalam dokumen d
# - *IDF(t)*: Inverse Document Frequency, ukuran yang menentukan seberapa sering sebuah term t muncul dalam corpus dokumen yang ada

# %%
# Classification using TFIDF vectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import xgboost as xgb

v = ""
# Vectorize training and testing data
def Vectorize(vec, X_train, X_test):    
    
    X_train_vec = vec.fit_transform(X_train)
    X_test_vec = vec.transform(X_test)
    
    v = vec
    print('Vectorization complete.\n')
    
    return X_train_vec, X_test_vec

# Use multiple classifiers and grid search for prediction
def ML_modeling(models, params, X_train, X_test, y_train, y_test):    
    
    if not set(models.keys()).issubset(set(params.keys())):
        raise ValueError('Some estimators are missing parameters')

    fitted_models = {}
    for key in models.keys():
    
        model = models[key]
        param = params[key]
        gs = GridSearchCV(model, param, cv=5, error_score=0, refit=True)
        gs.fit(X_train, y_train)
        y_pred = gs.predict(X_test)
        
        fitted_models[key] = gs
        
        # Print scores for the classifier
        print(key, ':', gs.best_params_)
        print("Precision: %1.3f \tRecall: %1.3f \t\tF1: %1.3f\n" % (precision_score(y_test, y_pred, average='macro'), recall_score(y_test, y_pred, average='macro'), f1_score(y_test, y_pred, average='macro')))
    
    return fitted_models

models = {
    'Naive Bayes': MultinomialNB(), 
    'Decision Tree': DecisionTreeClassifier(),  
    'Perceptron': MLPClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'XGBoost': xgb.XGBClassifier()
}

params = {
    'Naive Bayes': { 'alpha': [0.5, 0.75, 1], 'fit_prior': [True, False] }, 
    'Decision Tree': { 'min_samples_split': [1, 2, 5] }, 
    'Perceptron': { 'alpha': [0.0001, 0.001], 'activation': ['tanh', 'relu'] },
    'Gradient Boosting': { 'learning_rate': [0.05, 0.1], 'min_samples_split': [2, 5] },
    'XGBoost': { "max_depth": [3, 4, 5], "learning_rate": [0.1, 0.01, 0.05], "gamma": [0, 0.25, 1], "reg_lambda": [0, 1] }
}

# Encode label categories to numbers
enc = LabelEncoder()
df_prep['label'] = enc.fit_transform(df_prep['label'])
df_prep['question_clean'] = df_prep['question_clean'].apply(lambda x: " ".join(x)) 
labels = list(enc.classes_)

# Train-test split and vectorize
X_train, X_test, y_train, y_test = train_test_split(df_prep['question_clean'], df_prep['label'], test_size=0.2, random_state = 42)
X_train_vec, X_test_vec = Vectorize(TfidfVectorizer(), X_train, X_test)

fitted_models = ML_modeling(models, params, X_train_vec, X_test_vec, y_train, y_test)
# Out:
# Vectorization complete.
#
# Naive Bayes : {'alpha': 0.5, 'fit_prior': False}
# Precision: 0.794 	Recall: 0.799 		F1: 0.773
#
# Decision Tree : {'min_samples_split': 2}
# Precision: 0.546 	Recall: 0.504 		F1: 0.514
#
# Perceptron : {'activation': 'relu', 'alpha': 0.0001}
# Precision: 0.625 	Recall: 0.604 		F1: 0.600
#
# Gradient Boosting : {'learning_rate': 0.05, 'min_samples_split': 5}
# Precision: 0.626 	Recall: 0.580 		F1: 0.587
#
# XGBoost : {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'reg_lambda': 0}
# Precision: 0.681 	Recall: 0.667 		F1: 0.658

# %% [markdown]
# ### Export Model

# %%
fitted_models
# Out:
# {'Naive Bayes': GridSearchCV(cv=5, error_score=0, estimator=MultinomialNB(),
#               param_grid={'alpha': [0.5, 0.75, 1], 'fit_prior': [True, False]}),
#  'Decision Tree': GridSearchCV(cv=5, error_score=0, estimator=DecisionTreeClassifier(),
#               param_grid={'min_samples_split': [1, 2, 5]}),
#  'Perceptron': GridSearchCV(cv=5, error_score=0, estimator=MLPClassifier(),
#               param_grid={'activation': ['tanh', 'relu'],
#                           'alpha': [0.0001, 0.001]}),
#  'Gradient Boosting': GridSearchCV(cv=5, error_score=0, estimator=GradientBoostingClassifier(),
#               param_grid={'learning_rate': [0.05, 0.1],
#                           'min_samples_split': [2, 5]}),
#  'XGBoost': GridSearchCV(cv=5, error_score=0,
#               estimator=XGBClassifier(base_score=None, booster=None,
#                                       callbacks=None, colsample_bylevel=None,
#                                       colsample_bynode=None,
#                                       colsample_bytree=None,
#                                       early_stopping_rounds=None,
#                                       enable_categorical=False, eval_metric=None,
#                                       gamma=None, gpu_id=None, grow_policy=None,
#                                       importance_type=None,
#                                       interaction_constraints=None,
#                                       learning_rate=None, max_b...
#                                       max_cat_to_onehot=None,
#                                       max_delta_step=None, max_depth=None,
#                                       max_leaves=None, min_child_weight=None,
#                                       missing=nan, monotone_constraints=None,
#                                       n_estimators=100, n_jobs=None,
#                                       num_parallel_tree=None, predictor=None,
#                                       random_state=None, reg_alpha=None,
#                                       reg_lambda=None, ...),
#               param_grid={'gamma': [0, 0.25, 1],
#                           'learning_rate': [0.1, 0.01, 0.05],
#                           'max_depth': [3, 4, 5], 'reg_lambda': [0, 1]})}

# %%
# Naive Bayes Model
model_nb = fitted_models["Naive Bayes"]
# Vectorizer
vec = TfidfVectorizer()
X_train_vec = vec.fit_transform(X_train)

# save the model to disk
filename = 'model_nb.sav'
pickle.dump(model_nb, open(filename, 'wb'))
filename_vec = 'vectorizer.sav'
pickle.dump(vec, open(filename_vec, 'wb'))

# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
print(loaded_model)
loaded_vec = pickle.load(open(filename_vec, 'rb'))
print(loaded_vec)
# Out:
# GridSearchCV(cv=5, error_score=0, estimator=MultinomialNB(),
#              param_grid={'alpha': [0.5, 0.75, 1], 'fit_prior': [True, False]})
# TfidfVectorizer()

# %% [markdown]
# ## Predict

# %%
kalimat = "apa yang menyebabkan penyakit Grave"

kalimat_vec = loaded_vec.transform([kalimat])
pred = loaded_model.predict(kalimat_vec)
pred[0]
# Out:
# 5

# %%
kalimat = "definisi dari Grave"

kalimat_vec = loaded_vec.transform([kalimat])
pred = loaded_model.predict(kalimat_vec)
pred[0]
# Out:
# 6

# %%
kalimat = "anjay keren bgt"

kalimat_vec = loaded_vec.transform([kalimat])
pred = loaded_model.predict(kalimat_vec)
pred[0]
# Out:
# 0

# %%
df = pd.read_csv('label_description.csv')
df
# Out:
#    label                                        description
# 0    100  General question on the definition of Graves' ...
# 1    200  General question on the risk factors of Graves...
# 2    300  General question on the sign and symptoms of G...
# 3    400  General question on the diagnosis of Graves' d...
# 4    500  General question on the treatment choices of G...
# 5    600  General question on the complications caused b...
# 6    700  General question on the prognosis of Graves' d...
# 7    800  General question on the prevention of Graves' ...

# %%
# answer_json = {}
# url = "https://drive.google.com/file/d/1vkoMokpNXojHpJ7lpieLteabcG1pTDNs/view?usp=sharing"

# for i in range(len(df)):
#     jwb = "Jawaban dari kategori " + str(df.label[i]) + " " + df.description[i]
#     answer_json[int(df.label[i])] = {
#         "answer": [jwb],
#         "images": [url]
#     }

# %%
answer_json = []
url = "https://drive.google.com/file/d/1vkoMokpNXojHpJ7lpieLteabcG1pTDNs/view?usp=sharing"

for i in range(len(df)):
    jwb = "Jawaban dari kategori " + str(df.label[i]) + " " + df.description[i]
    ans = {
        "category": int(df.label[i]),
        "answer": [jwb],
        "images": [url]
    }
    answer_json.append(ans)

# %%
answer_json
# Out:
# [{'category': 100,
#   'answer': ["Jawaban dari kategori 100 General question on the definition of Graves' disease"],
#   'images': ['https://drive.google.com/file/d/1vkoMokpNXojHpJ7lpieLteabcG1pTDNs/view?usp=sharing']},
#  {'category': 200,
#   'answer': ["Jawaban dari kategori 200 General question on the risk factors of Graves' disease"],
#   'images': ['https://drive.google.com/file/d/1vkoMokpNXojHpJ7lpieLteabcG1pTDNs/view?usp=sharing']},
#  {'category': 300,
#   'answer': ["Jawaban dari kategori 300 General question on the sign and symptoms of Graves's disease"],
#   'images': ['https://drive.google.com/file/d/1vkoMokpNXojHpJ7lpieLteabcG1pTDNs/view?usp=sharing']},
#  {'category': 400,
#   'answer': ["Jawaban dari kategori 400 General question on the diagnosis of Graves' disease"],
#   'images': ['https://drive.google.com/file/d/1vkoMokpNXojHpJ7lpieLteabcG1pTDNs/view?usp=sharing']},
#  {'category': 500,
#   'answer': ["Jawaban dari kategori 500 General question on the treatment choices of Graves' disease"],
#   'images': ['https://drive.google.com/file/d/1vkoMokpNXojHpJ7lpieLteabcG1pTDNs/view?usp=sharing']},
#  {'category': 600,
#   'answer': ["Jawaban dari kategori 600 General question on the complications caused by Graves' disease"],
#   'images': ['https://drive.google.com/file/d/1vkoMokpNXojHpJ7lpieLteabcG1pTDNs/view?usp=sharing']},
#  {'category': 700,
#   'answer': ["Jawaban dari kategori 700 General question on the prognosis of Graves' disease"],
#   'images': ['https://drive.google.com/file/d/1vkoMokpNXojHpJ7lpieLteabcG1pTDNs/view?usp=sharing']},
#  {'category': 800,
#   'answer': ["Jawaban dari kategori 800 General question on the prevention of Graves' disease"],
#   'images': ['https://drive.google.com/file/d/1vkoMokpNXojHpJ7lpieLteabcG1pTDNs/view?usp=sharing']}]

# %%
import json
with open("answers.json", "w") as outfile:
    json.dump(answer_json, outfile)

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    label                                           question
# 0    500          Bagaimana cara mengobati penyakit Graves?
# 1    500                    Apa obat untuk penyakit Graves?
# 2    500  Obat apa yang dapat menyembuhkan penyakit Graves?
# 3    300                Apa gejala terkena penyakit Graves?
# 4    300     Bagaimana tanda-tanda terkena penyakit Graves?

# %%
question_json = []

for i in range(len(df)):
    q = {
        "label": int(df.label[i]),
        "question": df.question[i],
    }
    question_json.append(q)
    
question_json
# Out:
# [{'label': 500, 'question': 'Bagaimana cara mengobati penyakit Graves?'},
#  {'label': 500, 'question': 'Apa obat untuk penyakit Graves?'},
#  {'label': 500,
#   'question': 'Obat apa yang dapat menyembuhkan penyakit Graves?'},
#  {'label': 300, 'question': 'Apa gejala terkena penyakit Graves?'},
#  {'label': 300, 'question': 'Bagaimana tanda-tanda terkena penyakit Graves?'},
#  {'label': 300,
#   'question': 'Bagaimana cara tahu kita mengidap penyakit Graves?'},
#  {'label': 300, 'question': 'Apa gejala terkena penyakit Graves?'},
#  {'label': 200, 'question': 'Kenapa saya terkena penyakit Graves?'},
#  {'label': 700,
#   'question': 'Berapa lama waktu yang dibutuhkan untuk sembuh dari penyakit Graves?'},
#  {'label': 100,
#   'question': 'Apa hubungannya penyakit Graves dengan hipertiroidisme?'},
#  {'label': 700, 'question': 'Apakah penyakit Graves bisa sembuh sendiri?'},
#  {'label': 100, 'question': 'Apa itu penyakit Graves?'},
#  {'label': 100, 'question': 'Apa itu Graves disease?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves dan hipertiroid itu sama?'},
#  {'label': 200, 'question': 'Apakah penyakit Graves menyerang anak-anak?'},
#  {'label': 700,
#   'question': 'Apakah saya bisa meninggal karena penyakit Graves?'},
#  {'label': 700, 'question': 'Apakah penyakit Graves bisa sembuh?'},
#  {'label': 500, 'question': 'Bagaimana cara menyembuhkan penyakit Graves?'},
#  {'label': 800, 'question': 'Bagaimana supaya tidak kena penyakit Graves?'},
#  {'label': 300,
#   'question': 'Kapan saya harus ke dokter kalau kena penyakit Graves?'},
#  {'label': 300, 'question': 'Apa gejala penyakit Graves yang berbahaya?'},
#  {'label': 200,
#   'question': 'Siapa yang paling mungkin terkena penyakit Graves?'},
#  {'label': 200,
#   'question': 'Siapa yang paling mungkin menderita penyakit Graves?'},
#  {'label': 200, 'question': 'Siapa yang paling rentan kena penyakit Graves?'},
#  {'label': 200,
#   'question': 'Siapa yang paling beresiko kena penyakit Graves?'},
#  {'label': 500, 'question': 'Apakah penyakit Graves bisa diobati di rumah?'},
#  {'label': 700,
#   'question': 'Berapa lama supaya saya bisa sembuh dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Bagaimana rasanya kalau terkena penyakit Graves?'},
#  {'label': 200, 'question': 'Apa penyebab utama penyakit Graves?'},
#  {'label': 800, 'question': 'Bagaimana cara mencegah penyakit Graves?'},
#  {'label': 400, 'question': 'Apa pemeriksaan fungsi tiroid?'},
#  {'label': 300,
#   'question': 'Apa yang terjadi kalau kita kena penyakit Graves?'},
#  {'label': 400, 'question': 'Bagaimana kalau saya terkena penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves bisa menyebabkan penyakit lain?'},
#  {'label': 100, 'question': 'Apakah penyakit Graves berbahaya?'},
#  {'label': 100, 'question': 'Dari mana asal penyakit Graves?'},
#  {'label': 500, 'question': 'Apakah penyakit Graves harus operasi?'},
#  {'label': 600, 'question': 'Apa akibat dari penyakit Graves?'},
#  {'label': 400, 'question': 'Bagaimana cara mendeteksi penyakit Graves?'},
#  {'label': 400,
#   'question': 'Bagaimana saya tahu kalau saya kena penyakit Graves?'},
#  {'label': 600, 'question': 'Apa efek dari penyakit Graves?'},
#  {'label': 100, 'question': 'Apakah penyakit Graves langka?'},
#  {'label': 100,
#   'question': 'Apakah banyak orang yang menderita penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apa langkah yang harus diambil untuk mengatasi penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apa yang harus saya lakukan saat terkena penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apa yang harus saya perhatikan saat terkena penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apa saja obat yang perlu saya minum untuk penyakit Graves?'},
#  {'label': 300,
#   'question': 'Bagaimana ciri orang yang terkena penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apa saja penyakit yang berhubungan dengan penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apa yang perlu saya lakukan untuk menyembuhkan Graves Disease?'},
#  {'label': 600,
#   'question': 'Komplikasi apa saja yang dapat terjadi pada penyakit Graves?'},
#  {'label': 600, 'question': 'Apa komplikasi dari penyakit Graves?'},
#  {'label': 500, 'question': 'Apa rekomendasi obat untuk penyakit Graves?'},
#  {'label': 500,
#   'question': 'Bagaimana cara dokter mengobati penyakit Graves?'},
#  {'label': 300, 'question': 'Apa saja gejala penyakit Graves?'},
#  {'label': 500, 'question': 'Bagaimana cara penyakit Graves ditangani?'},
#  {'label': 500,
#   'question': 'Apa sih obat yang bagus untuk menyembuhkan Graves?'},
#  {'label': 400,
#   'question': 'Bagaimana cara dokter mendiagnosa penyakit Graves?'},
#  {'label': 400, 'question': 'Bagaimana diagnosis untuk penyakit Graves?'},
#  {'label': 500, 'question': 'Apa penanganan terbaik untuk penyakit Graves?'},
#  {'label': 400,
#   'question': 'Apa tes yang dilakukan untuk memeriksa sakit Graves?'},
#  {'label': 400,
#   'question': 'Apa yang dilakukan dokter untuk diagnosis sakit Graves?'},
#  {'label': 400, 'question': 'Bagaimana seseorang dikatakan menderita Graves?'},
#  {'label': 400, 'question': 'Tes apa saja untuk mengetahui Graves?'},
#  {'label': 400, 'question': 'Apa pemeriksaan untuk sakit Graves?'},
#  {'label': 400, 'question': 'Tes apa yang mengkonfirmasi sakit Graves?'},
#  {'label': 500,
#   'question': 'Apa pengobatan paling aman untuk penyakit Graves?'},
#  {'label': 400,
#   'question': 'Bagaimana dokter dapat mengetahui penyakit Graves?'},
#  {'label': 400, 'question': 'Bagaimana langkah mengetahui penyakit Graves?'},
#  {'label': 400, 'question': 'Cara dokter mendiagnosa Graves?'},
#  {'label': 400,
#   'question': 'Apa pemeriksaan yang perlu dilakukan untuk Graves?'},
#  {'label': 400, 'question': 'Bagaimana prosedur memeriksa penyakit Graves?'},
#  {'label': 400, 'question': 'Bagaimana cek saya menderita Graves?'},
#  {'label': 300, 'question': 'Apa tanda awal yang perlu saya perhatikan?'},
#  {'label': 400, 'question': 'Apa diagnosis awal untuk sakit Graves?'},
#  {'label': 400, 'question': 'Apa pemeriksaan yang perlu saya lakukan?'},
#  {'label': 400, 'question': 'Bagaimana cara memeriksa penyakit Graves?'},
#  {'label': 400, 'question': 'Apakah penyakit Graves dapat di diagnosa?'},
#  {'label': 400, 'question': 'Apa saja langkah pemeriksaan penyakit Graves?'},
#  {'label': 400,
#   'question': 'Apa tes yang perlu dilakukan untuk penyakit Graves?'},
#  {'label': 100, 'question': 'Apa hubungannya tiroid dengan penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apa makanan yang dapat menjadi penyembuh Graves?'},
#  {'label': 500, 'question': 'Makan apa yang bisa menyembuhkan Graves?'},
#  {'label': 100,
#   'question': 'Apakah Graves termasuk jenis penyakit yang berbahaya?'},
#  {'label': 300,
#   'question': 'Apakah tangan tremor menjadi tanda penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah tangan tremor menjadi gejala penyakit Graves?'},
#  {'label': 500, 'question': 'Apakah ada obat herbal untuk Graves?'},
#  {'label': 500, 'question': 'Apakah ada obat alami untuk penyakit Graves?'},
#  {'label': 500,
#   'question': 'Penyakit Graves apakah dapat diobati dengan obat alami?'},
#  {'label': 500,
#   'question': 'Penyakit Graves apakah dapat diobati dengan obat herbal?'},
#  {'label': 300,
#   'question': 'Apakah rambut memutih menjadi tanda dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apabila terkena Graves akan sering sakit lambung?'},
#  {'label': 200, 'question': 'Apakah wanita lebih sering terkena Graves?'},
#  {'label': 200,
#   'question': 'Apakah merokok meningkatkan risiko penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah sistem imun terganggu dengan adanya penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apa gejala yang paling sering terjadi pada penderita Graves?'},
#  {'label': 300,
#   'question': 'Apa gejala yang paling terlihat pada penderita Graves?'},
#  {'label': 400,
#   'question': 'Apa saja tes yang dilakukan untuk mendiagnosa penyakit Graves?'},
#  {'label': 400,
#   'question': 'Apa tes yang menjadi penunjang diagnosa penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apakah terapi yodium radioaktif menjadi obat Graves yang efektif?'},
#  {'label': 500,
#   'question': 'Apakah penderita penyakit Graves memerlukan operasi?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves merupakan penyakit autoimun?'},
#  {'label': 800,
#   'question': 'Bagaimana cara mengurangi risiko terkena penyakit Graves?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves merupakan penyakit genetik?'},
#  {'label': 600,
#   'question': 'Apakah gangguan jantung termasuk komplikasi dari penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah dapat terjadi keguguran bila saat hamil terkena penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah dapat terjadi kelahiran prematur bila saat hamil terkena penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apakah butuh terapi lanjutan setelah melakukan operasi tiroid?'},
#  {'label': 100, 'question': 'Jelaskan definisi penyakit Graves!'},
#  {'label': 100, 'question': 'Jelaskan apa itu penyakit Graves!'},
#  {'label': 100, 'question': 'Apakah yang dimaksud dengan penyakit Graves?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves berhubungan dengan hormon tubuh?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves dengan hormon Tiroid saling berkaitan?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves disebabkan oleh autoimun pada kelenjar Tiroid?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves disebabkan karena gangguan pada kelenjar Tiorid?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves menyebabkan kadar hormon Tiroid dalam tubuh meningkat drastis?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves merupakan salah satu penyakit metabolisme tubuh?'},
#  {'label': 500,
#   'question': 'Apakah penderita penyakit Graves harus minum obat seumur hidup?'},
#  {'label': 500,
#   'question': 'Obat apa saja yang perlu dikonsumsi oleh seseorang yang menderita penyakit Graves?'},
#  {'label': 700, 'question': 'Apakah penyakit Graves bisa sembuh total?'},
#  {'label': 200,
#   'question': 'Apa sajakah faktor yang menyebabkan seseorang mengalami penyakit Graves?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves sama dengan penyakit hipertioid?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves sama dengan penyakit hipertiroidisme?'},
#  {'label': 400,
#   'question': 'Bagaimana cara dokter mendiagnosis penyakit Graves pada seseorang?'},
#  {'label': 400,
#   'question': 'Apa sajakah jenis pemeriksaan yang harus dilalui untuk mendiagnosis penyakit Graves?'},
#  {'label': 400,
#   'question': 'Apakah seseorang perlu pemeriksaan kadar tiroid untuk mendiagnosis penyakit Graves?'},
#  {'label': 400,
#   'question': 'Apa saja pemeriksaan laboratorium yang diperlukan untuk mendiagnosis penyakit Graves?'},
#  {'label': 500,
#   'question': 'Dok, saya mau nanya saya sakit penyakit Graves dan masih mengonsumsi obat setiap harinya, apakah harus dikonsumsi setiap hari?'},
#  {'label': 300,
#   'question': 'Apakah Graves ophthalmopathy merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah keringat yang berlebihan merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah tidak tahan panas merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah jantung berdebar merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah berat badan turun merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Dok, saya mau nanya. Waktu itu saya ada keluhan ngga tahan panas, mudah capek, sama sering berdebar. Kata dokter saya kena penyakit Graves. Apakah benar, dok?'},
#  {'label': 200,
#   'question': 'Dok, ibu saya katanya pernah dibilang sakit Graves. Apakah saya berisiko untuk mengalami yang sama, dok?'},
#  {'label': 300,
#   'question': 'Jantung berdebar apakah salah satu gejala dari penyakit Graves?'},
#  {'label': 400,
#   'question': 'Dok, gimana sih caranya diagnosis penyakit Graves?'},
#  {'label': 400,
#   'question': 'Dok, katanya kalau periksa penyakit Graves itu pakai pemeriksaan kadar hormon Tiroid. Apakah itu benar, dok?'},
#  {'label': 400,
#   'question': 'Dok, apa saja jenis pemeriksaan buat penyakit Graves ya, dok?'},
#  {'label': 400,
#   'question': 'Dok, apakah pemeriksaan buat penyakit Graves harus lewat bagian radiologi ya, dok?'},
#  {'label': 400,
#   'question': 'Dari hasil lab kapan orang bisa dibilang penyakit Graves ya, dok?'},
#  {'label': 400,
#   'question': 'Apakah orang yang diduga sakit Graves perlu diperiksa kadar hormon Tiroid dan TSH nya ya, dok?'},
#  {'label': 500, 'question': 'Apa saja obat buat penyakit Tiroid ya, dok?'},
#  {'label': 600, 'question': 'Apa itu Graves ophthalmopathy?'},
#  {'label': 600,
#   'question': 'Apa saja komplikasi dari penyakit Graves ya, dok?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves bisa menyebabkan komplikasi ke mata?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves bisa menyebabkan komplikasi ke jantung?'},
#  {'label': 500,
#   'question': 'Apakah obat-obatan penyakit Graves aman untuk ibu-ibu hamil?'},
#  {'label': 500,
#   'question': 'Apakah ibu-ibu hamil tetap perlu minum obat Graves, dok?'},
#  {'label': 400,
#   'question': 'Apakah pemeriksaan penyakit Graves perlu dilakukan biopsi, dok?'},
#  {'label': 400,
#   'question': 'Pemeriksaan biopsi jarum halus untuk penyakit Graves?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves merupakan salah satu penyakit autoimun?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves merupakan salah satu gangguan sistem kekebalan tubuh?'},
#  {'label': 100, 'question': 'Apakah penyakit Graves perlu periksa ke dokter?'},
#  {'label': 500,
#   'question': 'Dok, saya sedang hamil. Apakah obat-obatan yang dikasih aman untuk ibu-ibu hamil?'},
#  {'label': 500,
#   'question': 'Apakah obat-obatan penyakit Graves aman untuk ibu-ibu yang sedang menyusui?'},
#  {'label': 500,
#   'question': 'Saya sedang menyusui anak saya yang baru lahir. Apakah obat-obatan yang dokter berikan aman, dok?'},
#  {'label': 500,
#   'question': 'Apakah setiap pasien yang menderita penyakit Graves harus dilakukan pembedahan?'},
#  {'label': 500,
#   'question': 'Dok, bener ngga ya kalau orang yang sakit Graves harus minum obat seumur hidup?'},
#  {'label': 500,
#   'question': 'Dok, saya dengar kalau orang yang sakit Graves harus minum obat lama. Apakah benar itu, dok?'},
#  {'label': 600,
#   'question': 'Apa saja komplikasi yang paling umum di penyakit Graves?'},
#  {'label': 300,
#   'question': 'Bagaimana ciri orang yang memiliki gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Dok, saya sering gampang ngantuk sama ngga tahan panas. Apakah itu salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Selamat pagi, dokter. Saya punya keluhan. Berat badan saya susah naik. Apakah itu salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah bola mata tampak menonjol merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah perasaan cemas dan mudah tersinggung merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah mudah lelah merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah gemetar pada tangan dan kaki merupakah salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah tremor merupakan salah satu gejala penyekiat Graves?'},
#  {'label': 300,
#   'question': 'Apakah penurunan berat badan, meskipun tidak ada perubahan dalam kebiasaan makan, merupakan salah satu gejala dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah pembesaran kelenjar tiroid merupakan salah gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah pembesaran kelenjar gondok merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah perubahan siklus menstruasi merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah disfungsi ereksi merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah penurunan gairah seksual merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah sering buang air besar merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah mata terasa sakit dan tertekan merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah mata memerah dan meradang merupakan salah satu gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah penglihatan ganda merupakan salah satu gejala penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah riwayat keluarga merupakan salah satu faktor risiko penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah jenis kelamin merupakan salah satu faktor risiko penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah usia merupakan salah satu faktor risiko penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah merokok merupakan salah satu faktor risiko penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah kehamilan merupakan salah satu faktor risiko penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah perempuan lebih berisiko terkena penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah perempuan lebih rentan mengalami penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah orang yang memiliki riwayat keluarga dengan penyakit Graves lebih berisiko daripada dengan yang tidak?'},
#  {'label': 200,
#   'question': 'Apakah stres bisa memicu munculnya penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah usia dibawah 40 tahun lebih berisiko mengalami penyakit Graves?'},
#  {'label': 400,
#   'question': 'Apakah orang dengan kecurigaan penyakit Graves perlu dilakukan pemeriksaan tes darah?'},
#  {'label': 400,
#   'question': 'Apakah orang dengan kecurigaan penyakit Graves perlu dilakukan pemeriksaan USG?'},
#  {'label': 500,
#   'question': 'Halo, dok. Saya sudah menderita penyakit Graves selama 9 tahun. Apakah saya masih perlu untuk mengonsumsi obat Tiroid?'},
#  {'label': 300,
#   'question': 'Apakah penderita Graves selalu mengalami jantung berdebar?'},
#  {'label': 600,
#   'question': 'Mata saya terasa mengganjal dan saya sudah menderita penyakit Graves selama 3 tahun. Apakah itu bagian dari komplikasi mata?'},
#  {'label': 300,
#   'question': 'Halo, dok. Perkenalkan nama saya Shinta. Kenapa saya mudah lelah, bahkan tidak bisa berdiri lama sebelumnya ya, dok? Kebetulan saya memang didiagnosis Graves disesase beberapa tahun lalu. Apakah itu bagian dari tanda penyakit Graves disesase, dok?'},
#  {'label': 600,
#   'question': 'Dokter saya mau nanya. Mata saya melotot akhir-akhir ini. Saya pernah dibilang sama dokter kalau saya punya penyakit Graves. Apakah penyakit Graves menyebabkan mata saya seperti ini, dok?'},
#  {'label': 500,
#   'question': 'Dokter, saya mau tanya. Kalau obat-obatan buat penyakit Graves itu apa saja ya, dok?'},
#  {'label': 500,
#   'question': 'Saya mau tau, kalau pengobatan buat penyakit Graves itu apakah selalu dengan obat-obatan atau perlu operasi juga ya, dok?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves bikin penglihatan seseorang terganggu?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves berhubungan dengan autoimun?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves berhubungan dengan gangguan sistem kekebalan tubuh?'},
#  {'label': 100,
#   'question': 'Apakah gangguan pada kelenjar Tiroid berperan dalam munculnya penyakit Graves?'},
#  {'label': 600,
#   'question': 'Dok, saya mau nanya. Kalau penyakit Graves ga diobatin akibatnya bisa apa saja ya, dok?'},
#  {'label': 600,
#   'question': 'Hai, dokter. Saya mau nanya nih, dok. Kalau penyakit Graves itu saya denger bisa menyebabkan gangguan jantung, paling ngga berdebar-debar. Itu benar ngga ya, dok? Terima kasih.'},
#  {'label': 500,
#   'question': 'Kira-kira tujuan ngobatin penyakit Graves itu apa ya, dok?'},
#  {'label': 500,
#   'question': 'Dok, saya mau bertanya. Saya menderita penyakti Graves sudah 1 tahun lamanya. Selama itu, saya rutin mengonsumsi obat-obatan rutin, salah satunya PTU. Tapi sejak satu bulan terakhir, ko mata saya jadi menonjol seperti ini. Kira-kira penyakit Graves ini bisa disembuhkan tidak ya, dok?'},
#  {'label': 600, 'question': 'Apa bahayanya dari penyakit Graves ini ya, dok?'},
#  {'label': 600,
#   'question': 'Apa saja empat bahaya utama dari penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves bisa mengakibatkan gangguan pada tulang dan osteoporosis, dok?'},
#  {'label': 600,
#   'question': 'Dok, nama saya Ani. Saya mau bertanya, dok. Saya baru saja menikah 1 tahun yang lalu. Saat ini saya belum punya anak. 4 bulan yang lalu, dokter bilang kalau saya terkena penyakit Graves. Kira-kira penyakit Graves ini mengganggu kesuburan saya tidak ya, dok?'},
#  {'label': 200,
#   'question': 'Apakah faktor genetik berpengaruh ke penyakit Graves?'},
#  {'label': 100,
#   'question': 'Perbedaan hipertiroidisme dengan penyakit Graves?'},
#  {'label': 600,
#   'question': 'Dokter, izin tanya. Kata orang penyakit Graves ini bisa bikin keropos tulang. Itu benar ngga ya, dok?'},
#  {'label': 600,
#   'question': 'Saya cari di internet katanya penyakit Graves ini bisa menyebabkan tulang jadi lemah dan akhirnya keropos. Itu fakta atau hoaks ya, dok?'},
#  {'label': 600,
#   'question': 'Kata dokter penyakit Graves bisa membuat gangguan kesuburan, apakah itu benar, dok?'},
#  {'label': 300,
#   'question': 'Mata melotot terus waspada penyakit Graves, benarkah?'},
#  {'label': 300,
#   'question': 'Dok sya punya masalah berat badan yang turun drastis, sering diare, dan susah tidur. Ditambah, akhir-akhir ini mata saya terasa menonjol dan tidak nyaman. Mohon jawabannya, dokter. Terima kasih.'},
#  {'label': 500,
#   'question': 'Selamat pagi, dokter. Perkenalkan nama saya Enzyy, saya mau bertanya tentang penyakit yang saya derita ini. Tiga bulan yang lalu saya datang ke dokter dengan keluhan susah tidur, sering BAB, dan badan terasa lemas. Saya sudah periksa darah dan kata dokter saya terkena penyakit Graves. Saya disuruh minum obat lama, katanya paling tidak satu tahun kemudian diperiksa lagi. Apakah ada cara cepat untuk penyembuhan penyakit saya ini, dok? Terima kasih.'},
#  {'label': 300,
#   'question': 'Sore, dokter. Saya mau bertanya leher sebelah kiri saya terasa lebih bengkak dan hangat, diraba kyknya sedikit agak keras. Kira-kira kenapa ya, dok? Terima kasih.'},
#  {'label': 600,
#   'question': 'Hallo, dokter. Saya Khansa, disini saya penderita penyakit Graves. Izin bertanya, dok. Saya sekarang merasa mata saya lebih menonjol, padahal saya sudah minum obat rutin. Kira-kira apakah ada jalan lain untuk pengobatan keluhan saya itu, dok? Terima kasih.'},
#  {'label': 500,
#   'question': 'Pagi dokter saya sekarang menderita penyakit Graves dan leher terasa bengkak dan tidak nyaman. Apakah ada saran agar leher saya tidak bengkak lagi, dok? Terima kasih.'},
#  {'label': 500,
#   'question': 'Dokter, saya seorang ibu berusia 34 tahun. Saat ini saya merasakan perbedaan mata kanan dan kiri saya. Mata kiri saya tampaknya lebih menonjol. Saya penderita hipertiroid sudah sejak 6 bulan yang lalu. Kalau seperti ini penanganannya seperti apa ya, dok? Terima kasih.'},
#  {'label': 400,
#   'question': 'Assalamualaikum, dokter. Saya disini seorang wanita usia 20 tahun. Saya resah dengan pembengkakan yang ada di leher kanan saya. Saya cari-cari di Internet katanya itu tanda penyakit Graves. Pemeriksaan apa yang harus saya jalani ya, dok? Terima kasih. Wassalmualaikum wr. wb.'},
#  {'label': 600,
#   'question': 'Dokter, saya baru kena penyakit Graves beberapa waktu ini. Saya seorang vokalis di salah satu band. Setelah saya didiagnosis penyakit Tiroid, saya merasa suara saya lebih serak. Apakah ini karena penyakit Graves saya ya, dok?'},
#  {'label': 500,
#   'question': 'Siang dok... Saya izin bertanya, tahun 2017 lalu saya sudah melakukan operasi tiroid karena masalah penyakit hipertiroid saya (penyakit Graves). Setelah operasi saya mendapatkan obat eutyrox agar mata saya tidak menonjol kembali. Apakah ini efektif, dok? Terima kasih.'},
#  {'label': 200,
#   'question': 'Selamat pagi, dokter. Saya baca di Internet kalau masalah hipertiroid, salah satunya penyakit Graves, sering ditemukan pada wanita muda, umumnya usia 20-40 tahun. Kira-kira itu kenapa ya, dok? Makasih.'},
#  {'label': 200,
#   'question': 'Pagi, dokter. Saya Murti, 24 tahun. Waktu tahun 2018 lalu ibu saya didiagnosis dokter penyakit Graves. Waktu itu gejalanya gemeteran dan suka keluar keringat. Nah, sekarang saya ada keluhan yang sama seperti ibu, ditambah berat badan yang turun drastis dan gelisah. Kira-kira apakah keluhan saya sekrang mirip dengan penyakit ibu yang waktu lalu itu?'},
#  {'label': 300,
#   'question': 'Met pagi, dok. Saya mau bertanya. Kata orang-orang dekat saya katanya mata kanan saya keliatan lebih menonjol. Padahal saya tidak ada keluhan apa-apa. Itu kira-kira kenapa ya, dok?'},
#  {'label': 300,
#   'question': 'Hallo, dokter. Saya mau menanyakan keluhan yang dialami oleh adik saya. Adik saya seorang pecandu game. Setiap hari, setiap selesai sekolah, kerjannya main game. Jadi ya udah biasa tuh ngeliatin layar berjam-jam. Tapi katanya akhir-akhir ini adik saya mengeluhkan matanya lebih menonjol dan mengganjal. Tidak sakit, tapi mengganggu. Terus juga, kyknya sekarang adik saya lebih kurusan, padahal dia makan kyknya normal-normal aja. Itu kenapa ya, dok? Terima kasih.'},
#  {'label': 300,
#   'question': 'Dokter, saya ngaca bola mata kanan saya keliatannya lebih menonjol. Rasanya mengganggu, tapi kalau dipencet juga rasanya sakit. Itu kira-kira kenapa ya, dok? Makasih.'},
#  {'label': 100,
#   'question': 'Dok, tanya dong. Penyakit Graves itu apa ya? Makasih'},
#  {'label': 400,
#   'question': 'Met siang, dok. Saya ada keluhan gelisah terus sering berdebar. Kata saudara, katanya hati-hati penyakit Graves. Saya jadi takut, dok. Harus periksa apa buat penyakit ini ya?'},
#  {'label': 600,
#   'question': 'Dokter mau tanya, dong. Baca di Internet katanya penyakit Graves bisa ngaruhin jantung. Kira-kira bisa bikin serangan jantung ngga ya? Makasih.'},
#  {'label': 200,
#   'question': 'Faktor risiko penyakit Graves ini apa saja selain faktor genetik keluarga ya, dok?'},
#  {'label': 500,
#   'question': 'Selamat pagi, dokter. Mohon maaf, saya izin konsultasi, dok. Saudara saya sudah 3 tahun mengalami penyakit Graves. Katanya dia selalu rutin minum obat, tapi rasanya ya tidak nyaman. Dia nanya, kira-kira penyakit Graves bisa sembuh tanpa obat tidak ya, dok? Misalnya operasi gitu, dok? Terima kasih.'},
#  {'label': 500,
#   'question': 'Apakah PTU merupakan obat untuk penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apakah methimazole merupakan obat untuk penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apakah obat-obatan penyakit Graves aman dikonsumsi untuk ibu-ibu hamil?'},
#  {'label': 300,
#   'question': 'Apakah benjolan di leher selalu dikaitkan dengan penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah penyakit Graves menyebabkan gangguan dalam konsentrasi?'},
#  {'label': 500,
#   'question': 'Kapan kita memerlukan operasi untuk penanganan penyakit Graves?'},
#  {'label': 200,
#   'question': 'Dokter, apakah penyakit Graves bisa menular, dok? Terima kasih.'},
#  {'label': 500,
#   'question': 'Selamat siang, dokter. Saya izin bertanya, dok. Kalau prinsip pengobatan pada penyakit Graves itu seperti apa ya, dok? Terima kasih.'},
#  {'label': 500,
#   'question': 'Assalamualaikum, dok. Saya Tiara, mau nanya, dok. Saya punya saudara yang sekarang sakit Graves. Didiagnosis baru 3 bulan lalu. Mau nanya, kalau pengobatannya hanya bisa dengan obat minum saja atau ada pilihan lainnya kah, dok? Terima kasih.'},
#  {'label': 500,
#   'question': 'Dokter, apakah semua penyakit Graves perlu dilakukan operasi, dok?'},
#  {'label': 500,
#   'question': 'Apakah obat-obatan penyakit Graves dapat menyebabkan efek samping bagi tubuh, dok?'},
#  {'label': 500,
#   'question': 'Selamat malam, dokter. Saya mendengar kalau obat buat penyakit Graves itu ada dua ya, dok. Namanya PTU dan Methimazole. Apakah kedua obat itu sama saja atau bagaimana ya, dok? Terima kasih.'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves sama dengan Graves disease?'},
#  {'label': 100, 'question': 'Apakah diagnosis banding dari penyakit Graves?'},
#  {'label': 600,
#   'question': 'Kenapa mata menonjol dapat terjadi pada penyakit Graves?'},
#  {'label': 200,
#   'question': 'Selain autoimun, faktor risiko apa lagi yang dapat menyebabkan penyakit Graves?'},
#  {'label': 400,
#   'question': 'Pemeriksaan darah pada diagnosis penyakit Graves untuk apa?'},
#  {'label': 100, 'question': 'Penyakit gangguan hormon tiroid akibat autoimun'},
#  {'label': 100,
#   'question': 'Penyakit kelebihan hormon tiroid akibat autoimun'},
#  {'label': 100,
#   'question': 'Hipertiroidisme akibat autoimum apakah selalu berarti penyakit Graves?'},
#  {'label': 200,
#   'question': 'Penyakit Graves lebih mungkin menyerang perempuan daripada laki-laki, apakah benar?'},
#  {'label': 200,
#   'question': 'Penyakit Graves lebih mungkin mengenai wanita daripada pria, apakah benar?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat menyebabkan kerusakan pada tulang dan osteoporosis?'},
#  {'label': 700,
#   'question': 'Apakah yang dimaksud dengan remisi penyakit Graves?'},
#  {'label': 700,
#   'question': 'Apakah mungkin penyakit Graves hilang selamanya dari tubuh?'},
#  {'label': 200,
#   'question': 'Apakah usia dan jenis kelamin berhubungan dengan kejadian penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah penyakit autoimun lain berhubungan dengan penyakit Graves?'},
#  {'label': 100, 'question': 'Graves disease adalah penyakit apa?'},
#  {'label': 100,
#   'question': 'Apakah penyebab penyakit Graves ini adalah virus?'},
#  {'label': 100,
#   'question': 'Apakah penyebab penyakit Graves ini adalah bakteri?'},
#  {'label': 200,
#   'question': 'Apakah kebiasaan merokok dapat menyebabkan penyakit Graves?'},
#  {'label': 200, 'question': 'Apakah stres dapat menyebabkan penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah tidak bisa ereksi saat berhubungan seksual merupakan salah satu gejala dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah sulit tidur dan rasa gelisah merupakan salah satu gejala dari penyakit Graves?'},
#  {'label': 500, 'question': 'Apakah obat methimazole itu?'},
#  {'label': 500, 'question': 'Apakah obat propilthiouracil (PTU) itu?'},
#  {'label': 300,
#   'question': 'Selamat siang, dokter. Anak saya yang berusia 6 tahun memilih keluhan mata yang menonjol disertai dengan keluhan kelopak warna yang berwarna kebiruan. Apakah itu merupakan hal yang wajar, dok?'},
#  {'label': 300,
#   'question': 'Siang, dokter. Saya mau bertanya, suami saya akhir-akhir ini mengalami keluhan mata kirinya seperti agak menonjol dan terasa tidak nyaman. Selain itu, matanya juga seperti keliatan kemerahan, berair, dan gatal. Sudah berobat ke dokter umum, tapi sepertinya belum membaik, dok. Mohon informasi sebaiknya apa yang harus saya lakukan, dokter? Terima kasih.'},
#  {'label': 500,
#   'question': 'Halo, dokter. Saya Yulia, 29 tahun. Saya sudah menderita penyakit Graves 6 tahun lamanya. Akan tetapi, baru kali ini saya merasakan sakit pada leher saya dan kini benjolan di leher saya berukuran seperti telur puyuh. Saya sempat rutin meminum obat yang diberikan, tetapi saat ini sedang tidak. Apakah ada solusi untuk saya, dokter? Terima kasih.'},
#  {'label': 300,
#   'question': 'Met, dokter. Suami saya belakangan ini matanya semakin menonjol dan tampak juling. Suami saya penderita Graves, tetapi selalu obat rutin. Apakah yang harus saya lakukan ya, dok? Terima kasih.'},
#  {'label': 100,
#   'question': 'Halo dok... Saya seorang wanita berusia 34 tahun. Akhir-akhir ini saya mengeluhkan badan lemas, mudah gemetar, dan penglihatan sedikit terganggu. Saya berkaca di depan cermin, tampaknya mata kiri saya terlihat lebih menonjol. Saya sudah datang ke dokter dan diperiksakan kadar TSH. Hasilnya tinggi dan saya dicurigai penyakit Graves. Saya takut dengan penyakit ini, apakah bisa sembuh, dok? Terima kasih.'},
#  {'label': 600,
#   'question': 'Hallo, dok. Disini saya seorang penderita penyakit Graves yang matanya menonjol. Mau tanya, dok.. Apakah ada jalan untuk pengobatan mata menonjol saya dengan semacam obat tetes? Supaya tidak merepotkan. Terima kasih.'},
#  {'label': 500,
#   'question': 'Pagi dokter... Saya penderita kelenjar tiroid yang terletak di depan leher saya. Keluhan benjolan di leher ini membuat saya tidak nyaman. Karena itu saya juga stress dan sakit kepala luar biasa. Apakah ada solusi untuk itu, dok? Makasih.'},
#  {'label': 400,
#   'question': 'Hallo, dok... Saya seorang remaja usia 18 tahun. Saya ada keluhan mata saya di kaca ko keliatan agak sedikit juling ya, dok. Saya sempet cerita ke ibu saya. Kata ibu saya, dulu pernah seperti itu juga dan masalahnya ada di kelenjar gondok. Katanya nama penyakitnya Graves disease. Saya diminta untuk periksa ke dokter. Apakah benar saya juga mengalami penyakit Graves? Terima kasih.'},
#  {'label': 300,
#   'question': 'Apakah mata juling selalu berarti penyakit Graves?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves disebabkan oleh kelenjar gondok?'},
#  {'label': 200,
#   'question': 'Apakah penyakit Graves lebih banyak terjadi pada perempuan?'},
#  {'label': 300,
#   'question': 'Mata tampak menonjol tanpa disadari, apakah itu salah satu tanda dan gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah penurunan berat badan drastis dan mata menonjol selalu berarti Graves disease?'},
#  {'label': 300,
#   'question': 'Apakah gejala mata membengkak, terasa berair, dan nyeri sudah beberapa bulan curiga penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah mata menonjol keluar dan kelopak mata yang sulit menutup artinya ada masalah dengan kelenjar gondok saya?'},
#  {'label': 100,
#   'question': 'Apakah nama lain dari penyakit Graves adalah hipertiroidisme Graves?'},
#  {'label': 100,
#   'question': 'Apakah nama lain dari penyakit Graves adalah toxic diffuse goiter?'},
#  {'label': 300,
#   'question': 'Apakan badan mudah merasa lelah, berat badan turun drastis, dan tidak kuat dengan panas adalah tanda dan gejala penyakit Graves?'},
#  {'label': 200,
#   'question': 'Jika seorang ibu yang menderita penyakit Graves memiliki seorang anak perempuan, apakah mungkin anak perempuannya juga mengalami penyakit Graves?'},
#  {'label': 500,
#   'question': 'Bolehkah penyakit Graves langsung dioperasi saja?'},
#  {'label': 600,
#   'question': 'Apakah risiko kesehatan jika penyakit Graves tidak diberikan pengobatan dengan tepat?'},
#  {'label': 300,
#   'question': 'Apakah salah satu gejala penyakit Graves pada perempuan adalah perubahan siklus haid?'},
#  {'label': 500, 'question': 'Terapi radioaktif iodin pada penyakit Graves?'},
#  {'label': 500,
#   'question': 'Obat betablocker pada penyakit Graves untuk apa?'},
#  {'label': 500,
#   'question': 'Apa saja indikasi pemberikan obat-obat untuk pasien dengan penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apakah obat-obatan untuk penyakit Graves memiliki efek samping?'},
#  {'label': 500,
#   'question': 'Apakah kontraindikasi pemberian obat-obatan untuk penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah salah tanda dan gejala dari penyakit Graves adalah otot-otot yang terasa lemas?'},
#  {'label': 300,
#   'question': 'Apakah periode menstruasi yang tidak teratur adalah salah satu dari tanda dan gejala penyakit Graves?'},
#  {'label': 600, 'question': 'Apakah eksoftalmus pada mata itu?'},
#  {'label': 400,
#   'question': 'Apakah tes fungsi tiroid pada pasien dengan kecurigaan penyakit Graves diperlukan?'},
#  {'label': 400,
#   'question': 'Apakah tes serapan yodium radioaktif pada pasien dengan kecurigaan penyakit Graves diperlukan?'},
#  {'label': 400,
#   'question': 'Apakah tes antibodi pada pasien dengan kecurigaan penyakit Graves diperlukan?'},
#  {'label': 600, 'question': 'Apakah oftalmopati Graves itu?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat mengakibatkan gangguan kehamilan?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat mengakibatkan gangguan pada jantung?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat mengakibatkan keadaan krisis tirotoksik?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat mengakibatkan kerapuhan pada tulang?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat mengakibatkan osteoporosis?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat mengakibatkan preeklamsia pada ibu-ibu hamil?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat mengakibatkan gangguan janin pada ibu-ibu yang sedang hamil?'},
#  {'label': 300,
#   'question': 'Apakah kondisi peningkatan fungsi tubuh seperti jantung berdebar-debar, keringat berlebih, berat badan turun tanpa pola merupakan gejala dari penyakit Graves?'},
#  {'label': 400,
#   'question': 'Apakah temuan laboratorium seperti peningkatan kadar hormon perangsung tiroid (TSH) merupakan gejala dari penyakit Graves?'},
#  {'label': 200,
#   'question': 'Mengapa wanita berusia 40 tahun berisiko mengalami penyakit Graves?'},
#  {'label': 400,
#   'question': 'Apakah pemeriksaan radioactive iodine uptake scan perlu dilakukan untuk menegakan diagnosis penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah sensitif terhadap suhu panas dan sering berkeringat merupakan salah satu tanda dan gejala dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah detak jantung yang cepat atau tidak teratur merupakan salah satu tanda dan gejala dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah keluhan sensitif terhadap cahaya yang disertai dengan mata menonjol merupakan salah satu gejala dari penyakit Graves?'},
#  {'label': 400,
#   'question': 'Tes darah seperti apa yang diperlukan untuk memastikan diagnosis penyakit Graves?'},
#  {'label': 400,
#   'question': 'Pemeriksaan fisik seperti apa yang diperlukan untuk memastikan kecurigaan penyakit Graves?'},
#  {'label': 400,
#   'question': 'Apakah pemeriksaan USG bermanfaat untuk mendiagnosis penyakit Graves?'},
#  {'label': 400,
#   'question': 'Apakah pemeriksaan radiologi seperti CT-Scan dan MRI bermanfaat untuk mendiagnosis penyakit Graves?'},
#  {'label': 500,
#   'question': 'Aapakah obat tiroid PTU memiliki efek samping untuk ibu-ibu hamil?'},
#  {'label': 500,
#   'question': 'Apakah obat tiroid Methimazole memiliki efek samping untuk ibu-ibu hamil?'},
#  {'label': 500,
#   'question': 'Kapan bisa dilakukan pembedahan untuk mengatasi Graves disease?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat mengakibatkan risiko keguguran pada ibu-ibu hamil?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves yang tidak ditangani dengan baik dapat mengakibatkan kejang-kejang?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves yang tidak ditangani dengan baik dapat mengakibatkan koma atau tidak sadarkan diri?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves yang tidak ditangani dengan baik dapat mengakibatkan mengigau (delirium)?'},
#  {'label': 600,
#   'question': 'Jika pada laki-laki, apakah sangat mungkin penyakit Graves mengakibatkan gangguan fungsi seksual?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves mungkin menyebabkan kematian pada penderitanya?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves jika mendapatkan pengobatan yang tepat dapat menghilang sepenuhnya?'},
#  {'label': 300,
#   'question': 'Apakah penurunan libido merupakan salah satu dari gejala Graves disease?'},
#  {'label': 300,
#   'question': 'Apakah buang air besar yang lebih sering merupakan salah satu dari gejala Graves disease?'},
#  {'label': 300,
#   'question': 'Apakah gangguan tidur merupakan salah satu dari gejala Graves disease?'},
#  {'label': 600,
#   'question': 'Apakah komplikasi penyakit Graves disease pada ibu-ibu hamil dapat mengakibatkan bayi lahir prematur?'},
#  {'label': 500,
#   'question': 'Apakah steroid dapat digunakan untuk mengobati penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apa saja yang termasuk gejala klasik Graves disease?'},
#  {'label': 400,
#   'question': 'Dari mana memulai pemeriksaan untuk penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apakah tiroidektomi dapat digunakan untuk mengatasi penyakit Graves disease?'},
#  {'label': 500,
#   'question': 'Apakah penggunaan propanolol dapat membantu mengatasi keluhan jantung berdebar pada penyakit Graves?'},
#  {'label': 300,
#   'question': 'Saya sering merasa kegerahan di suhu udara yang biasa saja, kira-kira kenapa ya, dok?'},
#  {'label': 300,
#   'question': 'Saya mengalami benjolan di leher, apakah itu salah satu tanda gangguan kelenjar gondok?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves menyebabkan siklus menstruasi tidak teratur?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves menyebabkan siklus haid tidak teratur?'},
#  {'label': 500, 'question': 'Bagaimana cara mengobati penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apakah pengangkatan kelenjar tiroid merupakan solusi dari penyakit Graves?'},
#  {'label': 100, 'question': 'Apakah penyakit Graves bisa disembuuhkan?'},
#  {'label': 400,
#   'question': 'Bagaimana cara dokter mendiagnosis Graves disease?'},
#  {'label': 300,
#   'question': 'Bagaimana kita mengenali tanda dan gejala dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Merasa mudah lelah padahal tidak melakukan apapun, apakah mungkin gejala dari ganggungan kelenjar tiroid?'},
#  {'label': 300,
#   'question': 'Apakah ada cara mudah mengetahui tanda dan gejala penyakit Graves?'},
#  {'label': 300,
#   'question': 'Mata sulit dipejamkan dan kering tanda penyakit Graves?'},
#  {'label': 100, 'question': 'Apakah penyebab utama dari penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apa saja faktor-faktor yang meningkatkan risiko seseorang mengalami penyakit Graves?'},
#  {'label': 100, 'question': 'Apakah penyakit Graves menular ke orang lain?'},
#  {'label': 100, 'question': 'Apa yang dimaksud dengan penyakit Graves?'},
#  {'label': 400,
#   'question': 'Apa saja pengobatan yang dapat diberikan untuk mengatasi penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah gugup dan mudah tersinggung merupakan gejala dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Berat badan turun drastis tanpa diet merupakan tanda penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah faktor keturunan berperan dalam risiko penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah riwayat operasi pada kelenjar tiroid salah satu faktor risiko penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah riwayat penyakit tiroid pada keluarga merupakan salah satu faktor risiko penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah kelemahan otot merupakan salah satu gejala dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah intoleran terhadap suhu panas merupakan salah satu gejala dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah diare merupakan salah satu gejala dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah mood swing merupakan salah satu gejala dari penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat mengakibatkan serangan jantung?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves pada ibu-ibu hamil dapat mengakibatkan hipertensi dalam kehamilan?'},
#  {'label': 400,
#   'question': 'Apa saja tes tiroid yang diperlukan untuk memastikan diagnosis penyakit Graves?'},
#  {'label': 300, 'question': 'Mata terus melotot, waspadai penyakit Graves?'},
#  {'label': 500,
#   'question': 'Terapi radioiodine untuk penyakit Graves, bisa kah dilakukan?'},
#  {'label': 500,
#   'question': 'Apakah terapi lini pertama untuk penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat mengakibatkan gagal jantung?'},
#  {'label': 300,
#   'question': 'Apakah sering buang air kecil merupakan gejala dari penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah orang yang memiliki gangguan sistem kekebalan tubuh berisiko mengalami penyakit Graves?'},
#  {'label': 200, 'question': 'Merokok menyebabkan penyakit Graves, benarkah?'},
#  {'label': 300,
#   'question': 'Apakah keluhan mata seperti rasa mengganjal, kesulitan menggerakkan mata, dan mata tampak menonjol merupakan tanda dan gejala dari penyakit Graves?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves disebabkan oleh sistem kekebalan tubuh yang menyerang dirinya sendiri?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves disebabkan oleh produksi hormon tiroid yang berlebihan?'},
#  {'label': 700, 'question': 'Apakah penyakit Graves bisa sembuh total?'},
#  {'label': 300,
#   'question': 'Apakah kelenjar gondok pada penyakit Graves selalu membesar?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves dapat mengakibatkan infertilitas pada pasangan?'},
#  {'label': 100, 'question': 'Apakah ada cara untuk mencegah penyakit Graves?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves termasuk ke dalam penyakit autoimun?'},
#  {'label': 600,
#   'question': 'Apakah dampak penyakit Grave terhadap kesehatan tulang?'},
#  {'label': 400, 'question': 'Bagaimana cara mengetahui penyakit Graves?'},
#  {'label': 400, 'question': 'Bagaimana saya tau Graves disease?'},
#  {'label': 700, 'question': 'Apakah penyakit Graves saya bisa sembuh?'},
#  {'label': 700, 'question': 'Apakah Graves disease bisa sembuh total?'},
#  {'label': 700,
#   'question': 'Apakah gejala penyakit Graves saya bisa membaik?'},
#  {'label': 700, 'question': 'Apakah gejala penyakit Graves sangat berat?'},
#  {'label': 800,
#   'question': 'Apakah dengan meminum herbal kita bisa sembuh dari penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah Graves pada perempuan hamil bisa membuat keguguran?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves pada ibu-ibu hamil bisa bikin darah tinggi?'},
#  {'label': 600, 'question': 'Benarkah Graves disease bikin tulang keropos?'},
#  {'label': 600, 'question': 'Bagaimana penyakit Graves bikin tulang keropos?'},
#  {'label': 600,
#   'question': 'Benarkah Graves bikin gangguan perkembangan janin?'},
#  {'label': 600,
#   'question': 'Benarkah Graves bikin gangguan pertumbuhan janin?'},
#  {'label': 600,
#   'question': 'Benarkah penyakit Graves membuat gangguan pertumbuhan dan perkembangan janin?'},
#  {'label': 600,
#   'question': 'Darah tinggi di ibu-ibu hamil karena penyakit Graves apakah benar?'},
#  {'label': 600,
#   'question': 'Sakit Graves bikin nyeri tulang dan gampang patah, benarkah?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves bikin sakit jantung bengkak?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves bikin risiko gagal jantung?'},
#  {'label': 600,
#   'question': 'Penyakit gagal jantung bisa disebabkan oleh penyakit Graves?'},
#  {'label': 600, 'question': 'Apakah penyakit Graves bikin janin terancam?'},
#  {'label': 600, 'question': 'Apakah penyakit Graves bisa bikin darah tinggi?'},
#  {'label': 800, 'question': 'Bagaimana mencegah penyakit Graves?'},
#  {'label': 800, 'question': 'Bagaimana mencegah Graves disease?'},
#  {'label': 800, 'question': 'Apakah ada cara untuk mencegah penyakit Graves?'},
#  {'label': 800, 'question': 'Cara mencegah penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah siklus menstruasi bisa terganggu karena penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah kesuburan wanita bisa terganggu karena penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah nyeri tulang tanda komplikasi penyakit Graves?'},
#  {'label': 800,
#   'question': 'Apakah ada makanan untuk mencegah penyakit Graves?'},
#  {'label': 800,
#   'question': 'Apakah ada obat herbal untuk mencegah Graves disease?'},
#  {'label': 700, 'question': 'Apakah gejala penyakit Graves bisa mendingan?'},
#  {'label': 600,
#   'question': 'Apakah mata bengkak salah satu tanda dari komplikasi penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves bikin kehilangan gairah seksual pada pria dewasa?'},
#  {'label': 600,
#   'question': 'Apakah masalah ereksi bisa disebabkan karena penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves bisa menyebabkan masalah pada penis?'},
#  {'label': 600,
#   'question': 'Apakah komplikasi penyakit Graves dapat mengakibatkan penurunan gairah seksual?'},
#  {'label': 600,
#   'question': 'Apakah Graves disease dapat mengakibatkan kematian pada seseorang?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves yang parah banget bisa bikin koma dan kejang-kejang?'},
#  {'label': 600,
#   'question': 'Apa saja macam-macam komplikasi dari Graves disease?'},
#  {'label': 600,
#   'question': 'Bagaimana penyakit Graves bisa bikin gangguan pada mata?'},
#  {'label': 600,
#   'question': 'Apakah gangguan ereksi pada penis pria berhubungan dengan penyakit Graves?'},
#  {'label': 800,
#   'question': 'Apakah obat herbal bisa membantu mencegah penyakit Graves?'},
#  {'label': 200,
#   'question': 'Bagaimana mengetahui faktor risiko penyakit Graves?'},
#  {'label': 300,
#   'question': 'Bagaimana mengenali ciri-ciri penyakit Graves dengan mudah?'},
#  {'label': 300,
#   'question': 'Apakah ciri-ciri penyakit Graves bisa dilihat dari lehernya?'},
#  {'label': 400, 'question': 'Apakah penyakit Graves perlu periksa darah?'},
#  {'label': 400, 'question': 'Apakah penyakit Graves perlu periksa radiologi?'},
#  {'label': 200,
#   'question': 'Siapa saja yang berisiko terkena penyakit Graves?'},
#  {'label': 200,
#   'question': 'Apakah anak kecil mungkin terkena penyakit Graves?'},
#  {'label': 400,
#   'question': 'Mengapa kita perlu perika fungsi tiroid untuk penyakit Graves?'},
#  {'label': 100,
#   'question': 'Apakah penyakit Graves disebabkan karena kadar hormon tiroid yang tinggi?'},
#  {'label': 100,
#   'question': 'Apa nama penyakit yang ditemukan oleh Robert Graves?'},
#  {'label': 100, 'question': 'Robert Graves menemukan peyakit apa?'},
#  {'label': 700, 'question': 'Apakah penyakit Graves bisa sembuh sendiri?'},
#  {'label': 300,
#   'question': 'Kapan sebaiknya kita periksa ke dokter untuk memastikan penyakit Graves?'},
#  {'label': 100, 'question': 'Apakah nama lain dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Benarkah degdegan salah satu gejala dari Graves disease?'},
#  {'label': 300,
#   'question': 'Benarkan gelisah saat tidur merupakan gejala dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Benarkah mata melotot dan sulit dipejamkan merupakan salah satu tanda dan gejala Graves disease?'},
#  {'label': 200,
#   'question': 'Wanita muda lebih berisiko mengalami penyakit Graves itu benar tidak?'},
#  {'label': 500, 'question': 'Obat PTU itu untuk penyakit apa?'},
#  {'label': 500, 'question': 'Obat methimazole itu untuk penyakit apa?'},
#  {'label': 400, 'question': 'Pemeriksaan kadar TSH itu untuk apa?'},
#  {'label': 500,
#   'question': 'Kapan pengangkatan kelenjar tiroid pada kasus Graves disease diperlukan?'},
#  {'label': 500,
#   'question': 'Apakah pengangkatan kelenjar tiroid selalu diperlukan?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves menyebabkan pria tidak perkasa?'},
#  {'label': 800,
#   'question': 'Apakah ada buah-buahan dan sayur-sayuran untuk mencegah penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apakah ada pengobatan alternatif untuk mengatasi penyakit Graves?'},
#  {'label': 500,
#   'question': 'Apakah pergi ke dukun bisa membantu menyembuhkan penyakit Graves saya?'},
#  {'label': 700,
#   'question': 'Apakah saya akan menderita penyakit Graves selamanya?'},
#  {'label': 700,
#   'question': 'Apakah itu artinya saya tidak akan pernah bisa sembuh dari penyakit Graves?'},
#  {'label': 700, 'question': 'Apakah gejala penyakit Graves saya bisa hilang?'},
#  {'label': 500,
#   'question': 'Apakah saya bisa pakai kemoterapi untuk mengobati penyakit Graves saya?'},
#  {'label': 800,
#   'question': 'Apakah minum kopi bisa mencegah saya dari penyakit Graves?)'},
#  {'label': 800,
#   'question': 'Apakah jinten hitam bisa membuat saya terhindar dari penyakit Graves?'},
#  {'label': 800,
#   'question': 'Apakah minum jus jambu biji bisa menjadi solusi saya terhindar dari penyakit Graves?'},
#  {'label': 700, 'question': 'Apakah Graves disease sebegitu bahayanya?'},
#  {'label': 700,
#   'question': 'Apakah penyakit Graves termasuk penyakit yang mematikan?'},
#  {'label': 600,
#   'question': 'Mungkinkah penyakit Graves menyerang ginjal saya?'},
#  {'label': 100, 'question': 'Apakah penyakit Graves itu kanker?'},
#  {'label': 100,
#   'question': 'Benarkah penyakit Graves itu merupakan salah satu bagian dari kanker?'},
#  {'label': 200,
#   'question': 'Benarkah penyakit Graves bisa menular melalui hubungan seksual?'},
#  {'label': 500,
#   'question': 'Apakah terapi sinar bisa menyembuhkan penyakit Graves saya?'},
#  {'label': 700,
#   'question': 'Apakah dengan penyakit Graves saya masih mungkin sehat kembali?'},
#  {'label': 700, 'question': 'Benarkah Graves disease menyebabkan mati cepat?'},
#  {'label': 300,
#   'question': 'Benarkah lemas terus sepanjang hari adalah salah satu gejala penyakit Graves?'},
#  {'label': 500,
#   'question': 'Benarkah pengangkatan kelenjar tiroid salah satu pilihan terapi penyakit Graves?'},
#  {'label': 700,
#   'question': 'Apakah benar Graves menyebabkan kecacatan seumur hidup?'},
#  {'label': 700,
#   'question': 'Apakah benar Graves disease ngga bisa sembuh selama-lamanya?'},
#  {'label': 700,
#   'question': 'Apakah saya perlu pasrah karena penyakit Graves saya ini?'},
#  {'label': 800,
#   'question': 'Apakah ada hal yang perlu saya lakukan supaya terhindar dari penyakit Graves?'},
#  {'label': 800,
#   'question': 'Apakah ada obat herbal untuk membantu saya terhindar dari penyakit Graves?'},
#  {'label': 800,
#   'question': 'Benarkah air rebusan jeruk nipis bisa membuat saya lebih sehat dan terhindar dari penyakit Graves?'},
#  {'label': 300,
#   'question': 'Apakah tanda-tandanya penyakit Graves itu sesak napas?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves bisa menyebabkan masalah di paru-paru saya?'},
#  {'label': 300,
#   'question': 'Benarkah penampilan kurus kering salah satu tanda dan gejala penyakit Graves?'},
#  {'label': 200, 'question': 'Apakah bayi mungkin terkena penyakit Graves?'},
#  {'label': 800,
#   'question': 'Benarkah mandi uap belerang bisa membantu badan saya lebih sehat dan mencegah penyakit Graves?'},
#  {'label': 700,
#   'question': 'Apakah penyakit Graves membuat kekhawatiran yang luar biasa?'},
#  {'label': 400,
#   'question': 'Saya harus periksa apa untuk memastikan penyakit Graves?'},
#  {'label': 100,
#   'question': 'Graves disease apakah adalah salah satu dari penyakit autoimun?'},
#  {'label': 500,
#   'question': 'Apakah operasi tiroidektomi direkomendasikan sebagai pilihan utama?'},
#  {'label': 600,
#   'question': 'Apakah penyakit Graves lama kelamaan bisa bikin penyakit gagal jantung kongestif?'},
#  {'label': 600,
#   'question': 'Apakah sesak napas, kaki bengkak, dan susah tidur dengan satu bantal salah satu gejala gagal jantung karena penyakit Graves?'},
#  {'label': 300,
#   'question': 'Benarkah ngga kuat suhu panas salah satu tanda Graves disease?'},
#  {'label': 300,
#   'question': 'Benarkah tangan dan kaki yang gemetaran salah satu gejala Graves disease?'},
#  {'label': 300,
#   'question': 'Benarkah berat badan turun drastis, kurus ceking salah satu tandanya penyakit Graves dalam tubuh?'},
#  {'label': 100,
#   'question': 'Kata dokter saya itu kena penyakit yang namanya Graves disease, tapi itu jenis penyakit apa ya?'},
#  {'label': 600,
#   'question': 'Apakah keropos tulang bisa lebih cepet terjadi di penderita penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah siklus menstruasi saya bisa kembali normal kalau saya minum obat-obat untuk penyakit Graves saya?'},
#  {'label': 300,
#   'question': 'Apakah benar tangan dan kaki kaku seperti robot itu salah satu cirinya penyakit Graves?'},
#  {'label': 600,
#   'question': 'Apakah krisis tiroid merupakan bentuk komplikasi paling parah dari penyakit Graves?'},
#  {'label': 700,
#   'question': 'Apakah Graves disease membuat saya lebih cepat meninggalkan dunia ini?'},
#  {'label': 200,
#   'question': 'Ibu saya seorang penderita Graves, apakah saya sangat berisiko mengalami hal yang serupa?'},
#  {'label': 700,
#   'question': 'Jika seseorang mengalami penyakit Graves apakah mungkin bisa sehat kembali seperti orang normal?'},
#  {'label': 500,
#   'question': 'Apa nama operasi yang bisa dilakukan untuk penyandang Graves disease?'}]

# %%
with open("questions.json", "w") as outfile:
    json.dump(question_json, outfile)

# %%
import pymongo

# Connect to mongoDB
MONGODB_URI = "mongodb+srv://holly:if5172@tiroidcluster.qzzri.mongodb.net/tiroidDB?retryWrites=true&w=majority"
client = pymongo.MongoClient(MONGODB_URI) 
db = client['tiroidDB']
print("Database loaded")
questions = db['questions']
# Out:
# Database loaded

# %%
questions
# Out:
# Collection(Database(MongoClient(host=['tiroidcluster-shard-00-02.qzzri.mongodb.net:27017', 'tiroidcluster-shard-00-01.qzzri.mongodb.net:27017', 'tiroidcluster-shard-00-00.qzzri.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-fan1sq-shard-0', tls=True), 'tiroidDB'), 'questions')

# %%
questions.find_one({'label': 500})['question']
# Out:
# 'Bagaimana cara mengobati penyakit Graves?'

# %%
q = pd.DataFrame(list(questions.find()))

# %%
q
# Out:
#                           _id  label  \
# 0    6266be1b5b3856abb22bd4bb    500
# 1    6266be1b5b3856abb22bd4bc    300
# 2    6266be1b5b3856abb22bd4bd    200
# 3    6266be1b5b3856abb22bd4be    300
# 4    6266be1b5b3856abb22bd4bf    500
# ..                        ...    ...
# 499  6266be1b5b3856abb22bd6ae    200
# 500  6266be1b5b3856abb22bd6af    500
# 501  6266be1b5b3856abb22bd6b0    600
# 502  6266be1b5b3856abb22bd6b1    700
# 503  6266c1d9c39fa95a7740603a    100
#
#                                               question         questions
# 0            Bagaimana cara mengobati penyakit Graves?               NaN
# 1    Bagaimana cara tahu kita mengidap penyakit Gra...               NaN
# 2                 Kenapa saya terkena penyakit Graves?               NaN
# 3       Bagaimana tanda-tanda terkena penyakit Graves?               NaN
# 4                      Apa obat untuk penyakit Graves?               NaN
# ..                                                 ...               ...
# 499  Ibu saya seorang penderita Graves, apakah saya...               NaN
# 500  Apa nama operasi yang bisa dilakukan untuk pen...               NaN
# 501  Apakah krisis tiroid merupakan bentuk komplika...               NaN
# 502  Jika seseorang mengalami penyakit Graves apaka...               NaN
# 503                                                NaN  pertanyaan dummy
#
# [504 rows x 4 columns]

# %%
# Insert new question
new_q = {
    "label": 100,
    "question": "pertanyaan dummy"
}
questions.insert_one(new_q)

# %%
# Full code
# Connect to mongoDB
MONGODB_URI = "mongodb+srv://holly:if5172@tiroidcluster.qzzri.mongodb.net/tiroidDB?retryWrites=true&w=majority"
client = pymongo.MongoClient(MONGODB_URI) 
db = client['tiroidDB']
print("Database loaded")
questions = db['questions']

# Convert mongoDB to dataframe
q = pd.DataFrame(list(questions.find()))

#### Input from Telegram Bot ####

#### Modeling ####

# Insert new question
def insertQuestion(label, question):
    new_q = {
        "label": label,
        "question": question
    }
    questions.insert_one(new_q)
